# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as opt

N = 15
x = np.linspace(0, 10, N)
y = 1 / (1 + np.e ** (-x))
y_noised = 1 / (1 + np.e ** (-x)) + 0.5 * np.random.randn(len(x))


def model(params, x):
    a, b = params
    return 1 / (1 + np.e ** (-x * a)) + b


def l1_fit(x0, x, y):
    y_pred = model(x0, x)
    return np.sum(np.abs(y - y_pred))


def l2_fit(x0, x, y):
    y_pred = model(x0, x)
    return np.sum(np.abs((y - y_pred) ** 2))


xopt1 = opt.fmin(func=l1_fit, x0=[1, 1], args=(x, y_noised))
xopt2 = opt.fmin(func=l2_fit, x0=[1, 1], args=(x, y_noised))

y_est1 = xopt1[1] + 1 / (1 + np.e ** (-x * xopt1[0]))
y_est2 = xopt2[1] + 1 / (1 + np.e ** (-x * xopt2[0]))


plt.subplot(411)
plt.plot(x, y_est1, 'y-')

plt.subplot(412)
plt.plot(x, y_est2, 'b-')

plt.subplot(413)
plt.plot(x, y_noised, 'g-')

plt.subplot(414)
plt.plot(x, y, 'g-')
plt.show()
# Out:
# ===============================================================================
#                                      CVXPY
#                                     v1.1.12
# ===============================================================================
# (CVXPY) May 04 12:27:00 PM: Your problem has 1000 variables, 1 constraints, and 0 parameters.
# (CVXPY) May 04 12:27:00 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 04 12:27:00 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 04 12:27:00 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:27:00 PM: Compiling problem (target solver=ECOS).
# (CVXPY) May 04 12:27:00 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) May 04 12:27:00 PM: Applying reduction Dcp2Cone
# (CVXPY) May 04 12:27:00 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 04 12:27:00 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 04 12:27:00 PM: Applying reduction ECOS
# (CVXPY) May 04 12:27:00 PM: Finished problem compilation (took 5.352e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:27:00 PM: Invoking solver ECOS  to obtain a solution.
# /home/kamil/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:556: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 1 times so far.
#
#   warnings.warn(msg, UserWarning)
# ECOS 2.0.7 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +1.779e-23  -0.000e+00  +6e+03  9e-01  1e-02  1e+00  3e+00    ---    ---    1  1  - |  -  -
#  1  +8.855e+01  +8.868e+01  +3e+03  8e-01  5e-03  6e-01  1e+00  0.6153  1e-01   0  1  1 |  0  0
#  2  +1.101e+02  +1.104e+02  +2e+03  6e-01  4e-03  7e-01  1e+00  0.4674  6e-01   1  0  0 |  0  0
#  3  +1.353e+02  +1.355e+02  +1e+03  3e-01  2e-03  4e-01  5e-01  0.6410  2e-01   1  0  0 |  0  0
#  4  +1.444e+02  +1.446e+02  +7e+02  2e-01  1e-03  3e-01  4e-01  0.4595  3e-01   1  0  0 |  0  0
#  5  +1.578e+02  +1.579e+02  +2e+02  5e-02  4e-04  1e-01  1e-01  0.9890  3e-01   1  0  0 |  0  0
#  6  +1.583e+02  +1.584e+02  +2e+02  4e-02  3e-04  9e-02  1e-01  0.4872  7e-01   1  0  1 |  0  0
#  7  +1.636e+02  +1.636e+02  +1e+02  2e-02  2e-04  6e-02  6e-02  0.9354  6e-01   1  0  1 |  0  0
#  8  +1.663e+02  +1.663e+02  +4e+01  8e-03  8e-05  2e-02  2e-02  0.6882  1e-01   1  1  1 |  0  0
#  9  +1.673e+02  +1.673e+02  +2e+01  4e-03  4e-05  1e-02  1e-02  0.6561  3e-01   1  1  1 |  0  0
# 10  +1.680e+02  +1.680e+02  +9e+00  2e-03  2e-05  5e-03  5e-03  0.9330  4e-01   1  1  1 |  0  0
# 11  +1.683e+02  +1.683e+02  +4e+00  8e-04  7e-06  2e-03  2e-03  0.6149  1e-01   1  1  1 |  0  0
# 12  +1.684e+02  +1.684e+02  +2e+00  4e-04  4e-06  1e-03  1e-03  0.6159  2e-01   1  1  1 |  0  0
# 13  +1.685e+02  +1.685e+02  +1e+00  2e-04  2e-06  5e-04  5e-04  0.6765  2e-01   1  1  1 |  0  0
# 14  +1.685e+02  +1.685e+02  +4e-01  8e-05  7e-07  2e-04  2e-04  0.6603  1e-01   1  1  1 |  0  0
# 15  +1.685e+02  +1.685e+02  +1e-01  2e-05  2e-07  6e-05  6e-05  0.9012  2e-01   1  1  1 |  0  0
# 16  +1.685e+02  +1.685e+02  +2e-02  4e-06  4e-08  1e-05  1e-05  0.8731  6e-02   1  1  1 |  0  0
# 17  +1.685e+02  +1.685e+02  +7e-03  1e-06  1e-08  4e-06  4e-06  0.6986  4e-02   1  1  1 |  0  0
# 18  +1.685e+02  +1.685e+02  +2e-03  3e-07  3e-09  9e-07  9e-07  0.7874  5e-02   1  1  1 |  0  0
# 19  +1.685e+02  +1.685e+02  +2e-04  4e-08  3e-10  1e-07  1e-07  0.9500  6e-02   1  1  1 |  0  0
# 20  +1.685e+02  +1.685e+02  +2e-05  4e-09  4e-11  1e-08  1e-08  0.9591  7e-02   1  1  1 |  0  0
# 21  +1.685e+02  +1.685e+02  +2e-07  4e-11  4e-13  1e-10  1e-10  0.9890  1e-04   1  0  0 |  0  0
#
# OPTIMAL (within feastol=4.3e-11, reltol=1.4e-09, abstol=2.3e-07).
# Runtime: 0.227568 seconds.
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:27:00 PM: Problem status: optimal
# (CVXPY) May 04 12:27:00 PM: Optimal value: 1.685e+02
# (CVXPY) May 04 12:27:00 PM: Compilation took 5.352e-02 seconds
# (CVXPY) May 04 12:27:00 PM: Solver (including time spent in interface) took 2.281e-01 seconds
# ===============================================================================
#                                      CVXPY
#                                     v1.1.12
# ===============================================================================
# (CVXPY) May 04 12:27:00 PM: Your problem has 1000 variables, 1 constraints, and 0 parameters.
# (CVXPY) May 04 12:27:00 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 04 12:27:00 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 04 12:27:00 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:27:00 PM: Compiling problem (target solver=ECOS).
# (CVXPY) May 04 12:27:00 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) May 04 12:27:00 PM: Applying reduction Dcp2Cone
# (CVXPY) May 04 12:27:00 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 04 12:27:00 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 04 12:27:00 PM: Applying reduction ECOS
# (CVXPY) May 04 12:27:00 PM: Finished problem compilation (took 4.868e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:27:00 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.7 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -0.000e+00  +6e+02  9e-02  5e-07  1e+00  3e+02    ---    ---    1  1  - |  -  -
#  1  +1.274e+00  +1.305e+00  +3e+01  4e-03  2e-08  7e-02  1e+01  0.9599  1e-04   2  2  2 |  0  0
#  2  +1.992e+01  +2.074e+01  +3e+00  5e-04  2e-09  8e-01  2e+00  0.9281  7e-02   3  3  3 |  0  0
#  3  +2.092e+01  +2.093e+01  +3e-02  6e-06  2e-11  9e-03  2e-02  0.9890  1e-04   2  2  2 |  0  0
#  4  +2.093e+01  +2.093e+01  +3e-04  6e-08  2e-13  1e-04  2e-04  0.9890  1e-04   2  2  2 |  0  0
#  5  +2.093e+01  +2.093e+01  +4e-06  7e-10  2e-15  1e-06  2e-06  0.9890  1e-04   2  1  1 |  0  0
# /home/kamil/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:556: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 2 times so far.
#
#   warnings.warn(msg, UserWarning)
#  6  +2.093e+01  +2.093e+01  +4e-08  9e-12  3e-17  1e-08  3e-08  0.9890  1e-04   2  1  1 |  0  0
#
# OPTIMAL (within feastol=8.5e-12, reltol=1.9e-09, abstol=4.1e-08).
# Runtime: 0.150346 seconds.
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:27:01 PM: Problem status: optimal
# (CVXPY) May 04 12:27:01 PM: Optimal value: 2.093e+01
# (CVXPY) May 04 12:27:01 PM: Compilation took 4.868e-02 seconds
# (CVXPY) May 04 12:27:01 PM: Solver (including time spent in interface) took 1.515e-01 seconds
