# %% [markdown]
# ## Zadanie 1

# %%
import numpy as np
from scipy.linalg import norm
import matplotlib.pyplot as plt
import scipy.optimize as opt
# %matplotlib inline

x = np.sort(np.random.uniform(0, 20, 30))
y_noised = x**2 + 0.1 * np.random.randn(len(x))
y_true = x**2

def model(params, x):
  a,b,c = params
  return a*x**2 +b*x +c
def l1_fit(x0,x,y):
  y_pred = model(x0,x)
  return np.sum(np.abs(y-y_pred))

def l2_fit(x0,x,y):
  y_pred = model(x0,x)
  return np.sum(np.abs((y-y_pred)**2))


xopt1 = opt.fmin(func=l1_fit, x0=[1,1,1], args=(x, y_noised));
xopt2 = opt.fmin(func=l2_fit, x0=[1, 1,1], args=(x, y_noised));

y_est1 =xopt1[2] + xopt1[1]*x + xopt1[0] * x**2
y_est2 = xopt2[2] + xopt2[1]*x + xopt2[0] * x**2
err_l1 = np.abs(y_true-y_est1)
err_l2 = np.abs(y_true-y_est2)
fig, ax = plt.subplots(4,1,figsize=(10,8),constrained_layout=True)
ax[0].plot(x,y_noised,'*')
ax[1].plot(x,y_noised,'*')
ax[2].plot(x,y_noised,'*')
ax[0].plot(x,y_true,'k', label = 'oryginal')
ax[0].set_title('original')
ax[1].plot(x,y_est1,'g-',label='l1 norm')
ax[1].set_title('norm l1')
ax[2].plot(x,y_est2,'r-',label='l2 norm')
ax[2].set_title('norm l2')
ax[3].plot(x,err_l1,label = 'error l1')
ax[3].plot(x,err_l2,label = 'error l2')
ax[3].set_title('error')
plt.legend()
# Out:
# Optimization terminated successfully.
#          Current function value: 2.275552
#          Iterations: 87
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 0.247679
#          Iterations: 127
#          Function evaluations: 227

# %% [markdown]
# ##Zadanie 2

# %%
t = np.linspace(-5,5,1000)
y = np.sin(2*np.pi*t)

def autocorrelate(sig,r):
  N =  len(sig)
  return sum([sig[i]*sig[i-r] for i in range(N-r)])/(N-r)

def find_zeros(sig):
  N = len(sig)
  for i in range(N):
      cor = autocorrelate(sig,i)
      if  np.abs(cor) < 0.01 :
        return [t[j] for j in range(0,N,2*i)]
  print('No periods found')
zeros = find_zeros(y)
zeros_val = [0 for i in range(len(zeros))]
plt.plot(t,y)
plt.scatter(zeros,zeros_val)

# %% [markdown]
# ##Zadanie 3

# %%
import pandas as pd
t = np.random.uniform(-5,5,2000)
x = 3*np.sin(np.pi*t)+4*sin(2*np.pi*3*t) + 5*np.sin(np.pi*10*t)
sc = pd.Series(x)


def sigyy(y,M):
  K = len(y)
  mean = y_est2.mean()
  return [sum([(y[i]-mean)*(y[i-m]-mean) for k in range(K)])/(K-1) for m in range(M)]
def k(y):
  K = len(y)
  std = y.std()
  mean = y.mean()
  return (sum([(y[i]mean)**2 for i in range(K)])/K)/std**4
def TKEO(y):
  return [y[i]**2-y[i+1]*y[i-1] for i in range(len(y))]

for i in sc:
  print(i)
  print(sigyy(sc,500))
  print(k(sc))
  print(TKEO(sc))
# Out:
#   File "<ipython-input-46-6133f34ee7c9>", line 15
#     return (sum([(y[i]mean)**2 for i in range(K)])/K)/std**4
#                          ^
# SyntaxError: invalid syntax
